# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/energydata_complete.csv')
df
# Out:
#                   date  Appliances  lights         T1       RH_1         T2  \
# 0      1/11/2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      1/11/2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      1/11/2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      1/11/2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      1/11/2016 17:40          60      40  19.890000  46.333333  19.200000
# ...                ...         ...     ...        ...        ...        ...
# 19730  5/27/2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  5/27/2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  5/27/2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  5/27/2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  5/27/2016 18:00         430      10  25.500000  46.600000  25.264286
#
# ...

# %%
 # upload this to Colab
df.head()
# Out:
#               date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  1/11/2016 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  1/11/2016 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  1/11/2016 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  1/11/2016 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  1/11/2016 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9  T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56   6.48        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50   6.37        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40   6.25        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40   6.13        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
print(df['lights'].unique())
# Out:
# [30 40 50 70 60 10 20  0]

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
# 3. Shape and info
print(df.shape)
df.info()
# Out:
# (19735, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
# 4. Check duplicates
print(df.duplicated().sum())
print(df.isnull().sum())
# Out:
# 0
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
# 7. IQR function
def iqr(data):
    Q1 = np.percentile(data, 20)
    Q3 = np.percentile(data, 80)
    return Q3 - Q1

# %%
def iqr_outliers(column):
    Q1 = np.percentile(column, 20)
    Q3 = np.percentile(column, 80)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return ((column < lower) | (column > upper)).sum()

# Apply to all numeric columns
for col in df.select_dtypes(include=['number']).columns:
    outlier_count = iqr_outliers(df[col])
    print(f"{col}: {outlier_count} outliers")
# Out:
# Appliances: 1916 outliers
# lights: 647 outliers
# T1: 33 outliers
# RH_1: 20 outliers
# T2: 165 outliers
# RH_2: 77 outliers
# T3: 4 outliers
# RH_3: 0 outliers
# T4: 0 outliers
# RH_4: 0 outliers
# T5: 20 outliers
# RH_5: 976 outliers
# T6: 70 outliers
# RH_6: 0 outliers
# T7: 0 outliers
# RH_7: 0 outliers
# T8: 0 outliers
# RH_8: 0 outliers
# T9: 0 outliers
# RH_9: 0 outliers
# T_out: 76 outliers
# Press_mm_hg: 17 outliers
# RH_out: 26 outliers
# Windspeed: 45 outliers
# Visibility: 740 outliers
# Tdewpoint: 0 outliers
# rv1: 0 outliers
# rv2: 0 outliers

# %%
df.head()
# Out:
#               date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  1/11/2016 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  1/11/2016 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  1/11/2016 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  1/11/2016 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  1/11/2016 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9  T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56   6.48        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50   6.37        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40   6.25        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40   6.13        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
df.shape
# Out:
# (19735, 29)

# %%
# 8. Calculate IQR for 'Appliances'
print("Appliances IQR:", iqr(df['Appliances']))
# Out:
# Appliances IQR: 60.0

# %%
# 9. Correlation heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm', annot=False)
plt.title("Correlation Heatmap")
plt.show()

# %%
# 10. Distribution of target
sns.histplot(df['Appliances'],kde=True)
plt.title("Distribution of Appliances Energy Usage")
plt.show()

# %%
# 11. Line plot over time
plt.figure(figsize=(14,6))
plt.plot(df['date'], df['Appliances'], color='purple')
plt.title("Energy Usage Over Time")
plt.xlabel("Time")
plt.ylabel("Appliances Energy (Wh)")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of numerical columns to plot (excluding 'date')
numeric_cols = [
    'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3',
    'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8',
    'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
    'Visibility', 'Tdewpoint', 'rv1', 'rv2']

# Plot boxplots in a loop
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col], color='skyblue')
    plt.title(f'Boxplot of {col}')
    plt.grid(True)
    plt.show()

# %%
data_numeric = df[numeric_cols]

# Combined boxplot
plt.figure(figsize=(16, 6))
sns.boxplot(data=data_numeric, palette="Set3")
plt.xticks(rotation=90)  # Rotate labels for readability
plt.title("Boxplots of All Numerical Columns")
plt.grid(True)
plt.show()

# %%
# time series plot Show how energy usage (Appliances) changes over time.
df['date'] = pd.to_datetime(df['date'])
df.set_index('date')['Appliances'].plot(figsize=(12, 5), title='Appliance Energy Usage Over Time')
# Out:
# <Axes: title={'center': 'Appliance Energy Usage Over Time'}, xlabel='date'>

# %%
#histogram Understand the distribution of Appliances, lights, temperature, and humidity.
df['Appliances'].hist(bins=50)
# Out:
# <Axes: >

# %%
#heatmap Understand how features are related to each other and to the target variable.
import seaborn as sns
corr = df.corr()
plt.figure(figsize=(20,18))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
#Pair Plot : Visualize pairwise relationships between multiple features.
sns.pairplot(df[['Appliances', 'lights', 'T1', 'RH_1']])

# %%
#Boxplot Detect outliers in temperature and humidity data
sns.boxplot(data=df[['T1', 'T2', 'T3', 'T4']])
# Out:
# <Axes: >

# %%
#Line Plots of Temp & Humidity: Compare temperature/humidity across rooms.
df.set_index('date')[['T1', 'T2', 'T3', 'T4']].plot(figsize=(12,6), title='Temperature Across Rooms')
# Out:
# <Axes: title={'center': 'Temperature Across Rooms'}, xlabel='date'>

# %%
df_new=df.drop(['date'],axis=1)
df_new.columns
df_new
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Appliances   19735 non-null  int64
#  1   lights       19735 non-null  int64
#  2   T1           19735 non-null  float64
#  3   RH_1         19735 non-null  float64
#  4   T2           19735 non-null  float64
#  5   RH_2         19735 non-null  float64
#  6   T3           19735 non-null  float64
#  7   RH_3         19735 non-null  float64
#  8   T4           19735 non-null  float64
#  9   RH_4         19735 non-null  float64
#  10  T5           19735 non-null  float64
#  11  RH_5         19735 non-null  float64
#  12  T6           19735 non-null  float64
#  13  RH_6         19735 non-null  float64
#  14  T7           19735 non-null  float64
#  15  RH_7         19735 non-null  float64
#  16  T8           19735 non-null  float64
#  17  RH_8         19735 non-null  float64
# ...

# %%
columns_list = [
    'RH_1', 'RH_2', 'RH_3', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9',
    'Press_mm_hg', 'Tdewpoint',  'rv2', 'T3', 'T4', 'T5', 'T8',
            'Visibility', 'RH_out', ' Windspeed'
]

# %%
df_new.isnull().sum()
# Out:
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
# Fill NaNs in numeric columns with median
df_new.fillna(df_new.median(numeric_only=True), inplace=True)
df_new.isnull().sum()
# Out:
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split



# Define features and target
x = df_new.drop(columns=[ "Appliances",])
y = df_new["Appliances"]

# Split into training and testing sets (80/20 split)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=52)

# %%
# Print unique values for each column in df_new
for column in df_new.columns:
    print(f"Unique values in {column}:")
    print(df_new[column].unique())
    print("-" * 30)
# Out:
# Unique values in Appliances:
# [  60   50   70  230  580  430  250  100   90   80  140  120  190  110
#   400  390  240   40   30  310  380  370   20  260  500  450  220  170
#   290  130  200  210  180  350  300  340  150  330  420  520  360  270
#   550  690  620  610  490  410  320  740  910  510  790  460  160  480
#   280  560 1080  750  470  440  800  540  530  660  630  600   10  570
#   830 1070  890  590  850  710  680  670  780  640  650  700  770  720
#   760  860  880  730  900  820  870  840]
# ------------------------------
# Unique values in lights:
# [30 40 50 70 60 10 20  0]
# ------------------------------
# Unique values in T1:
# [19.89       19.85666667 19.79       19.92666667 20.06666667 20.13333333
#  20.26       20.42666667 20.56666667 20.73       20.85666667 20.89
#  20.96333333 21.03333333 21.1        21.13333333 21.2        21.29
#  21.35666667 21.39       21.5        21.53333333 21.6        21.26
# ...

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
linear = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
linear
# Out:
#         Predicted  Actual
# 17987  143.868553     100
# 887    124.989173     120
# 19067   84.597508      60
# 14252   92.057583      60
# 3378    87.681581      50
# ...           ...     ...
# 17343   61.165123      50
# 85      80.738045      50
# 13462   83.215545      50
# 18651   75.609117      60
# 2346    71.026203      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.17180737688458714

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_pred)
# Out:
# 51.97237741005178

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 8185.141420116191

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.6132696487630319

# %%
model.coef_
# Out:
# array([ 2.01462317e+00, -1.06738788e+00,  1.57533829e+01, -1.76560347e+01,
#        -1.37686730e+01,  2.50767842e+01,  4.15681977e+00, -3.27959858e+00,
#        -4.32316771e-01,  6.44389970e-01,  1.66194715e-01,  6.60722832e+00,
#         3.30660301e-01,  6.49889490e-01, -1.40209076e+00,  8.67921148e+00,
#        -4.85385464e+00, -1.54100727e+01, -5.12283784e-01, -1.00532308e+01,
#         1.30015693e-01, -1.18273949e+00,  1.77875251e+00,  1.25150226e-01,
#         5.55021817e+00, -2.38391564e-02, -2.38391564e-02])

# %%
model.intercept_
# Out:
# np.float64(81.35714728049484)

# %%
from sklearn.model_selection import KFold, cross_val_score

# Define the number of folds for cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=52)

# Perform cross-validation
scores = cross_val_score(model, x_train, y_train, cv=kfold, scoring='r2')

# Print the cross-validation scores
print("Cross-validation R-squared scores:", scores)
print("Mean R-squared score:", scores.mean())
# Out:
# Cross-validation R-squared scores: [0.16103865 0.17544458 0.16388339 0.15704639 0.13729489]
# Mean R-squared score: 0.15894157954738347

# %%
from sklearn.svm import SVR

# %%
model = SVR(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([97.75693673, 97.44729502, 63.29438456, ..., 52.67374423,
#        56.02977209, 39.89527355])

# %%
svm = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
svm
# Out:
#        Predicted  Actual
# 17987  97.756937     100
# 887    97.447295     120
# 19067  63.294385      60
# 14252  65.103302      60
# 3378   57.628480      50
# ...          ...     ...
# 17343  57.739495      50
# 85     49.790908      50
# 13462  52.673744      50
# 18651  56.029772      60
# 2346   39.895274      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.03212093674523342

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 43.685763299577495

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 9565.681689494892

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(97.80430302136452)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 0.3451272691334961
# 34.51272691334961

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=5)

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 86., 266.,  56., ...,  52.,  52.,  46.])

# %%
knn = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
knn
# Out:
#        Predicted  Actual
# 17987       86.0     100
# 887        266.0     120
# 19067       56.0      60
# 14252       58.0      60
# 3378        48.0      50
# ...          ...     ...
# 17343       80.0      50
# 85         110.0      50
# 13462       52.0      50
# 18651       52.0      60
# 2346        46.0      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.19856756203951464

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 46.61464403344312

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 7920.66683557132

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(88.99812827004465)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 0.4826202569374009
# 48.26202569374009

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 90., 120.,  60., ...,  50., 460.,  40.])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#        Predicted  Actual
# 17987       90.0     100
# 887        120.0     120
# 19067       60.0      60
# 14252       40.0      60
# 3378        40.0      50
# ...          ...     ...
# 17343       50.0      50
# 85          70.0      50
# 13462       50.0      50
# 18651      460.0      60
# 2346        40.0      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.14800382046319605

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 40.022802128198634

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 8420.395236888777

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(91.76271158204065)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 0.3844163303722239
# 38.44163303722239

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 10), dpi=132)
plot_tree(model, fontsize=8)
plt.show()
#plt.savefig('out.pdf')

# %%
from sklearn.model_selection import KFold, cross_val_score

# Define the number of folds for cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=52)

# Perform cross-validation
scores = cross_val_score(model, x_train, y_train, cv=kfold, scoring='r2')

# Print the cross-validation scores
print("Cross-validation R-squared scores:", scores)
print("Mean R-squared score:", scores.mean())
# Out:
# Cross-validation R-squared scores: [-0.00743969 -0.09264488  0.06417738  0.07251385 -0.00816777]
# Mean R-squared score: 0.005687777130102911

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 93.2, 160.5,  57.6, ...,  76.5,  71.8,  40.4])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#        Predicted  Actual
# 17987       93.2     100
# 887        160.5     120
# 19067       57.6      60
# 14252       58.2      60
# 3378        44.4      50
# ...          ...     ...
# 17343       57.4      50
# 85          82.4      50
# 13462       76.5      50
# 18651       71.8      60
# 2346        40.4      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5538881695733303

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 32.72591841905244

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 4408.984479351407

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(66.40018433220955)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 0.33884704950133987
# 33.88470495013399

# %%
# Create Random Forest Regressor object
clf = RandomForestRegressor(n_estimators=300, criterion="poisson", max_depth=None,min_samples_split=5,min_samples_leaf=2,random_state=82, bootstrap=True) # 'absolute_error', 'poisson', 'squared_error', 'friedman_mse'

# Train Random Forest Regressor
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5510425801288287

# %%
from sklearn.ensemble import BaggingRegressor
model = BaggingRegressor()
model.fit(x_train, y_train)
# Out:
# BaggingRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 91., 129.,  53., ...,  60., 118.,  40.])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#        Predicted  Actual
# 17987       91.0     100
# 887        129.0     120
# 19067       53.0      60
# 14252       51.0      60
# 3378        46.0      50
# ...          ...     ...
# 17343       59.0      50
# 85         124.0      50
# 13462       60.0      50
# 18651      118.0      60
# 2346        40.0      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5040008850672537

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 34.886749429946796

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 4902.027362553838

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(70.01447966352274)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 0.36236016188600495
# 36.236016188600495

# %%
# Create Bagging Regressor object
from sklearn.tree import DecisionTreeRegressor
base_estimator = DecisionTreeRegressor(max_depth=20, random_state=80)
br = BaggingRegressor(estimator=base_estimator, n_estimators=20, bootstrap=True)

# Train Bagging Regressor
br = br.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = br.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.5175797452005437

# %%
from sklearn.ensemble import AdaBoostRegressor
model=AdaBoostRegressor()
model.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([275.10427807, 343.74085235, 221.33443846, ..., 358.51464968,
#        356.88208323, 301.2654925 ])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#         Predicted  Actual
# 17987  275.104278     100
# 887    343.740852     120
# 19067  221.334438      60
# 14252  361.126888      60
# 3378   204.991954      50
# ...           ...     ...
# 17343  195.021608      50
# 85     354.366577      50
# 13462  358.514650      50
# 18651  356.882083      60
# 2346   301.265492      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -4.355876411488302

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 216.926047762902

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 52932.8620336999

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(230.0714281124449)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 3.806353041559998
# 380.63530415599985

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([127.19140819, 115.68593217,  70.72566042, ...,  66.40617767,
#         90.88908997,  44.56264386])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#         Predicted  Actual
# 17987  127.191408     100
# 887    115.685932     120
# 19067   70.725660      60
# 14252   99.636397      60
# 3378    58.127009      50
# ...           ...     ...
# 17343   56.137726      50
# 85      93.943211      50
# 13462   66.406178      50
# 18651   90.889090      60
# 2346    44.562644      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.29380418278951437

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 46.44574667080252

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 6979.430234983912

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(83.54298435526415)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 0.5357241387362277
# 53.57241387362277

# %%
# Create Boosting Regressor object
br = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, loss='quantile', criterion='squared_error') #'quantile', 'huber', 'absolute_error', 'squared_error'

# Train Boosting Regressor
br = br.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = br.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# -0.43681355516798503

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([111.02609 ,  99.243286,  53.544365, ...,  57.964947,  62.075066,
#         29.537088], dtype=float32)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#         Predicted  Actual
# 17987  111.026093     100
# 887     99.243286     120
# 19067   53.544365      60
# 14252   66.373718      60
# 3378    43.557133      50
# ...           ...     ...
# 17343   56.258823      50
# 85      74.967667      50
# 13462   57.964947      50
# 18651   62.075066      60
# 2346    29.537088      40
#
# [3947 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5316329002380371

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 35.68906021118164

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 4628.935546875

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(68.03628110703141)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape
# Out:
# 0.3835422694683075
# 38.35422694683075

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
model = SVR()
param_grid = {
    'kernel': ['linear', 'poly', 'rbf']
}

# %%
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("Best Parameters:", best_params)
print("Best Cross-validation mse:", grid_search.best_score_)
print("mse", mse)
# Out:
# Best Parameters: {'kernel': 'linear'}
# Best Cross-validation mse: -10352.99024689429
# mse 9565.681689494892

# %%
#  using Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=42)
param_grid = {
     'n_estimators': [100, 200, 300],
     'max_depth': [None, 10, 20],
     'min_samples_split': [2, 5, 10]
}

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("Best Parameters:", best_params)

print("mse", mse)
# Out:
# Best Parameters: {'kernel': 'linear'}
# mse 9565.681689494892

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# R-squared: 0.03212093674523342

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", mape)
# Out:
# MAPE: 0.3451272691334961

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)
import pandas as pd

# Define split ratios
splits = {
    "70:30": 0.30,
    "80:20": 0.20,
    "75:25": 0.25,
    "60:40": 0.40,
    "85:15": 0.15
}

results = []

# Loop through splits
for split_name, test_size in splits.items():
    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=test_size, random_state=42
    )

    # Train Linear Regression
    model = LinearRegression()
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    # Evaluate
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)

    results.append([split_name, r2, mae, mse, mape])
    print(f"\n===== Results for {split_name} =====")
    print(f"R²:   {r2:.4f}")
    print(f"MAE:  {mae:.4f}")
    print(f"MSE:  {mse:.4f}")
    print(f"MAPE: {mape:.4f}")

# Convert to DataFrame for summary
results_df = pd.DataFrame(results, columns=["Split", "R2", "MAE", "MSE", "MAPE"])
print("\n===== Summary Table =====")
print(results_df)
# Out:
# ===== Results for 70:30 =====
# R²:   0.1672
# MAE:  52.9227
# MSE:  8579.6535
# MAPE: 0.6226
#
# ===== Results for 80:20 =====
# R²:   0.1693
# MAE:  52.5447
# MSE:  8312.7595
# MAPE: 0.6292
#
# ===== Results for 75:25 =====
# R²:   0.1590
# MAE:  52.7463
# MSE:  8354.8390
# MAPE: 0.6263
#
# ===== Results for 60:40 =====
# R²:   0.1507
# MAE:  53.5707
# MSE:  9163.9526
# MAPE: 0.6086
#
# ===== Results for 85:15 =====
# R²:   0.1803
# MAE:  51.6831
# MSE:  7815.9796
# MAPE: 0.6192
#
# ===== Summary Table =====
#    Split        R2        MAE          MSE      MAPE
# 0  70:30  0.167236  52.922732  8579.653539  0.622590
# 1  80:20  0.169313  52.544733  8312.759514  0.629181
# 2  75:25  0.158953  52.746309  8354.839038  0.626258
# 3  60:40  0.150692  53.570659  9163.952618  0.608570
# 4  85:15  0.180298  51.683131  7815.979574  0.619246

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (
    RandomForestRegressor,
    BaggingRegressor,
    AdaBoostRegressor,
    GradientBoostingRegressor
)
from xgboost import XGBRegressor
import pandas as pd

# Define models
models = {
    "SVR": SVR(),
    "KNN": KNeighborsRegressor(),
    "DecisionTree": DecisionTreeRegressor(random_state=42),
    "RandomForest": RandomForestRegressor(random_state=42),
    "Bagging": BaggingRegressor(random_state=42),
    "AdaBoost": AdaBoostRegressor(random_state=42),
    "GradientBoosting": GradientBoostingRegressor(random_state=42),
    "XGBRegressor": XGBRegressor(random_state=42, verbosity=0)
}

# Define split ratios
splits = {
    "70:30": 0.30,
    "80:20": 0.20,
    "75:25": 0.25,
    "60:40": 0.40,
    "85:15": 0.15
}

results = []

# Loop through models and splits
for model_name, model in models.items():
    for split_name, test_size in splits.items():
        X_train, X_test, y_train, y_test = train_test_split(
            x, y, test_size=test_size, random_state=42
        )
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Evaluation metrics
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        mape = mean_absolute_percentage_error(y_test, y_pred)

        results.append([model_name, split_name, r2, mae, mse, mape])
        print(f"\n===== {model_name} ({split_name}) =====")
        print(f"R²:   {r2:.4f}")
        print(f"MAE:  {mae:.4f}")
        print(f"MSE:  {mse:.4f}")
        print(f"MAPE: {mape:.4f}")

# Convert to DataFrame for summary
results_df = pd.DataFrame(results, columns=["Model", "Split", "R2", "MAE", "MSE", "MAPE"])
print("\n===== Summary Table =====")
print(results_df)
# Out:
# ===== SVR (70:30) =====
# R²:   -0.1056
# MAE:  48.9182
# MSE:  11390.9162
# MAPE: 0.3767
#
# ===== SVR (80:20) =====
# R²:   -0.1007
# MAE:  47.8879
# MSE:  11014.3080
# MAPE: 0.3728
#
# ===== SVR (75:25) =====
# R²:   -0.1024
# MAE:  47.9714
# MSE:  10951.3404
# MAPE: 0.3728
#
# ===== SVR (60:40) =====
# R²:   -0.1122
# MAE:  49.9897
# MSE:  12000.6235
# MAPE: 0.3748
#
# ===== SVR (85:15) =====
# R²:   -0.1009
# MAE:  47.3939
# MSE:  10497.3920
# MAPE: 0.3700
#
# ===== KNN (70:30) =====
# R²:   0.1681
# MAE:  47.7696
# MSE:  8570.5671
# MAPE: 0.4947
#
# ===== KNN (80:20) =====
# R²:   0.1757
# MAE:  46.8513
# MSE:  8248.7145
# MAPE: 0.4830
#
# ===== KNN (75:25) =====
# R²:   0.1765
# MAE:  46.9716
# MSE:  8180.3218
# MAPE: 0.4883
#
# ===== KNN (60:40) =====
# R²:   0.1716
# MAE:  48.7175
# MSE:  8938.0441
# MAPE: 0.4942
#
# ===== KNN (85:15) =====
# R²:   0.1726
# MAE:  46.0675
# MSE:  7889.6440
# MAPE: 0.4807
#
# ===== DecisionTree (70:30) =====
# R²:   0.1358
# MAE:  40.5540
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X=x

# %%
x.head()
# Out:
#    lights     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0      30  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1      30  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2      30  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3      40  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4      40  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9  T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53   6.60        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56   6.48        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50   6.37        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40   6.25        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40   6.13        733.9    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("Variance Inflation Factor (VIF) for each feature:")
display(vif_data.sort_values(by='VIF',ascending=False))
# Out:
# Variance Inflation Factor (VIF) for each feature:
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#         feature          VIF
# 26          rv2          inf
# 25          rv1          inf
# 1            T1  3606.583756
# 17           T9  2594.662887
# 3            T2  2504.855959
# 4          RH_2  2171.424609
# 20  Press_mm_hg  2086.964820
# 2          RH_1  1645.939486
# 13           T7  1614.282018
# 6          RH_3  1567.992544
# 8          RH_4  1394.008872
# 21       RH_out  1297.427031
# 5            T3  1239.199422
# 9            T5  1187.589724
# 7            T4  1027.204346
# 15           T8   984.862189
# 18         RH_9   640.538210
# 16         RH_8   583.062976
# 14         RH_7   519.430546
# 19        T_out   399.357743
# 24    Tdewpoint   132.367673
# 11           T6    89.040546
# 10         RH_5    45.210967
# ...

# %%
from statsmodels.tools.tools import add_constant

df_vif = X.copy()


while True:
    X = add_constant(df_vif)
    vif_data = pd.DataFrame()
    vif_data["feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    vif_data = vif_data[vif_data["feature"] != "const"]

    max_vif = vif_data["VIF"].max()

    if max_vif > 10:
        feature_to_drop = vif_data.loc[vif_data["VIF"].idxmax(), "feature"]
        print(f"Dropping '{feature_to_drop}' with VIF: {max_vif:.2f}")
        df_vif.drop(columns=[feature_to_drop], inplace=True)
    else:
        break

x_cleaned = add_constant(df_vif)
vif_data = pd.DataFrame()
vif_data["feature"] = x_cleaned.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_data = vif_data[vif_data["feature"] != "const"]

print("\nFinal VIF values:")
print(vif_data.sort_values(by="VIF", ascending=False))
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# Dropping 'rv1' with VIF: inf
# Dropping 'T_out' with VIF: 146.68
# Dropping 'T2' with VIF: 28.40
# Dropping 'T9' with VIF: 27.36
# Dropping 'T6' with VIF: 23.51
# Dropping 'RH_4' with VIF: 15.68
# Dropping 'T7' with VIF: 12.19
# Dropping 'T1' with VIF: 10.47
#
# Final VIF values:
#         feature       VIF
# 5          RH_3  9.170405
# 2          RH_1  8.675917
# 10         RH_7  8.427743
# 9          RH_6  7.904333
# 7            T5  7.793544
# 4            T3  7.523072
# 12         RH_8  6.947819
# 6            T4  6.429954
# 13         RH_9  5.741477
# 3          RH_2  5.214215
# 11           T8  4.863068
# 18    Tdewpoint  4.661810
# 15       RH_out  4.599757
# 16    Windspeed  1.513151
# 8          RH_5  1.327587
# 14  Press_mm_hg  1.313524
# 1        lights  1.172192
# 17   Visibility  1.034534
# ...

# %%
x_cleaned.head(5)
# Out:
#    const  lights       RH_1       RH_2     T3       RH_3         T4  \
# 0    1.0      30  47.596667  44.790000  19.79  44.730000  19.000000
# 1    1.0      30  46.693333  44.722500  19.79  44.790000  19.000000
# 2    1.0      30  46.300000  44.626667  19.79  44.933333  18.926667
# 3    1.0      40  46.066667  44.590000  19.79  45.000000  18.890000
# 4    1.0      40  46.333333  44.530000  19.79  45.000000  18.890000
#
#           T5   RH_5       RH_6       RH_7    T8       RH_8   RH_9  \
# 0  17.166667  55.20  84.256667  41.626667  18.2  48.900000  45.53
# 1  17.166667  55.20  84.063333  41.560000  18.2  48.863333  45.56
# 2  17.166667  55.09  83.156667  41.433333  18.2  48.730000  45.50
# 3  17.166667  55.09  83.423333  41.290000  18.1  48.590000  45.40
# 4  17.200000  55.09  84.893333  41.230000  18.1  48.590000  45.40
#
#    Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint        rv2
# 0        733.5    92.0   7.000000   63.000000        5.3  13.275433
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Assuming your target is 'Appliances'
x_train, x_test, y_train, y_test = train_test_split(
    x_cleaned, y, test_size=0.2, random_state=42
)

# Scale the data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

def evaluate_model(y_true, y_pred, model_name="Model"):
    print(f"📊 Results for {model_name}")
    print("R²:", round(r2_score(y_true, y_pred), 4))
    print("MSE:", round(mean_squared_error(y_true, y_pred), 4))
    print("MAE:", round(mean_absolute_error(y_true, y_pred), 4))
    print("MAPE:", round(mean_absolute_percentage_error(y_true, y_pred) * 100, 2), "%")
    print("-"*40)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200, max_depth=15, random_state=42)
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
evaluate_model(y_test, y_pred, "Random Forest")
# Out:
# 📊 Results for Random Forest
# R²: 0.4759
# MSE: 5244.9052
# MAE: 35.9636
# MAPE: 39.31 %
# ----------------------------------------

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
evaluate_model(y_test, y_pred, "KNN Regressor")
# Out:
# 📊 Results for KNN Regressor
# R²: 0.3736
# MSE: 6268.4794
# MAE: 38.0877
# MAPE: 37.2 %
# ----------------------------------------

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=42)
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
evaluate_model(y_test, y_pred, "XGBoost Regressor")
# Out:
# 📊 Results for XGBoost Regressor
# R²: 0.4681
# MSE: 5322.7959
# MAE: 36.9012
# MAPE: 39.52 %
# ----------------------------------------

# %%
from sklearn.ensemble import BaggingRegressor

bagging = BaggingRegressor(n_estimators=100, random_state=42)
bagging.fit(x_train, y_train)
y_pred = bagging.predict(x_test)
evaluate_model(y_test, y_pred, "Bagging Regressor")
# Out:
# 📊 Results for Bagging Regressor
# R²: 0.5219
# MSE: 4784.7907
# MAE: 33.0394
# MAPE: 34.22 %
# ----------------------------------------

# %%
from sklearn.ensemble import AdaBoostRegressor

ada = AdaBoostRegressor(n_estimators=200, learning_rate=0.1, random_state=42)
ada.fit(x_train, y_train)
y_pred = ada.predict(x_test)
evaluate_model(y_test, y_pred, "AdaBoost Regressor")
# Out:
# 📊 Results for AdaBoost Regressor
# R²: -1.4687
# MSE: 24704.7047
# MAE: 145.8801
# MAPE: 248.64 %
# ----------------------------------------

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(n_estimators=200, learning_rate=0.1, max_depth=5, random_state=42)
gbr.fit(x_train, y_train)
y_pred = gbr.predict(x_test)
evaluate_model(y_test, y_pred, "Gradient Boosting Regressor")
# Out:
# 📊 Results for Gradient Boosting Regressor
# R²: 0.4076
# MSE: 5927.8595
# MAE: 39.9573
# MAPE: 44.35 %
# ----------------------------------------

# %%
import tensorflow as tf
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([
                            tf.keras.layers.Dense(10),
                            tf.keras.layers.Dense(5),
                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam

model.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model.fit(x_train, y_train, epochs= 10, verbose=1)
# Out:
# Epoch 1/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 95.2699 - mae: 95.2699
# Epoch 2/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 51.8390 - mae: 51.8390
# Epoch 3/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.4431 - mae: 44.4431
# Epoch 4/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.2435 - mae: 44.2435
# Epoch 5/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 44.1862 - mae: 44.1862
# Epoch 6/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 44.1585 - mae: 44.1585
# Epoch 7/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.1479 - mae: 44.1479
# Epoch 8/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.1390 - mae: 44.1390
# Epoch 9/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.1349 - mae: 44.1349
# Epoch 10/10
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.1301 - mae: 44.1301

# %%
model.evaluate(x_test, y_test)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.0816 - mae: 41.0816
# [43.614627838134766, 43.614627838134766]

# %%
model.summary();
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 815 (3.19 KB)
#  Trainable params: 271 (1.06 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 544 (2.13 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model1= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model1.compile(
    loss=tf.keras.losses.MeanAbsoluteError(),
    optimizer=tf.keras.optimizers.SGD(),
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.MeanSquaredError(name="mse"),
        tf.keras.metrics.MeanAbsolutePercentageError(name="mape")
    ]
)


# STEP1: Fit the model

history= model1.fit(x_train, y_train, epochs= 200, verbose=0)

# %%
model1.evaluate(x_test, y_test)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.5137 - mae: 37.5137 - mape: 31.5806 - mse: 7290.2939
# [40.00831985473633, 40.00831985473633, 8567.1259765625, 32.10947799682617]

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(7, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(3, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train, y_train, epochs= 400)
# Out:
# Epoch 1/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 91.9093 - mae: 91.9093
# Epoch 2/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 49.3145 - mae: 49.3145
# Epoch 3/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 45.7731 - mae: 45.7731
# Epoch 4/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.6850 - mae: 44.6850
# Epoch 5/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.0848 - mae: 44.0848
# Epoch 6/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 43.7483 - mae: 43.7483
# Epoch 7/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 43.5170 - mae: 43.5170
# Epoch 8/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 43.3503 - mae: 43.3503
# Epoch 9/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 43.2111 - mae: 43.2111
# Epoch 10/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 43.0961 - mae: 43.0961
# Epoch 11/400
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 42.9891 - mae: 42.9891
# Epoch 12/400
# ...

# %%
model2.evaluate(x_test, y_test)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.3884 - mae: 37.3884
# [39.60401916503906, 39.60401916503906]

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
df_new.shape
# Out:
# (19735, 28)

# %%
# 70/30 split
split_ratio = 0.3
split_name = "70/30"

print(f"--- Training with {split_name} split ---")

# Split the data
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(
    x_cleaned, y, test_size=split_ratio, random_state=42
)

# Scale the data
scaler_split = StandardScaler()
x_train_split_scaled = scaler_split.fit_transform(x_train_split)
x_test_split_scaled = scaler_split.transform(x_test_split)

# Create and compile the deep learning model (reusing model2 architecture)
model2_split = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(7, activation='relu'),
    tf.keras.layers.Dense(5, activation='relu'),
    tf.keras.layers.Dense(3, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

model2_split.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[tf.keras.metrics.MeanAbsoluteError(name="mae")]
)

# Fit the model
history_split = model2_split.fit(x_train_split_scaled, y_train_split, epochs=500, verbose=0)

# Evaluate the model
y_pred_split = model2_split.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_split, f"Deep Learning Model ({split_name} split)")
# Out:
# --- Training with 70/30 split ---
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Deep Learning Model (70/30 split)
# R²: 0.1494
# MSE: 8763.1348
# MAE: 40.42
# MAPE: 31.92 %
# ----------------------------------------

# %%
# 75/25 split
split_ratio = 0.25
split_name = "75/25"

print(f"--- Training with {split_name} split ---")

# Split the data
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(
    x_cleaned, y, test_size=split_ratio, random_state=42
)

# Scale the data
scaler_split = StandardScaler()
x_train_split_scaled = scaler_split.fit_transform(x_train_split)
x_test_split_scaled = scaler_split.transform(x_test_split)

# Create and compile the deep learning model (reusing model2 architecture)
model2_split = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(7, activation='relu'),
    tf.keras.layers.Dense(5, activation='relu'),
    tf.keras.layers.Dense(3, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

model2_split.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[tf.keras.metrics.MeanAbsoluteError(name="mae")]
)

# Fit the model
history_split = model2_split.fit(x_train_split_scaled, y_train_split, epochs=500, verbose=0)

# Evaluate the model
y_pred_split = model2_split.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_split, f"Deep Learning Model ({split_name} split)")
# Out:
# --- Training with 75/25 split ---
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Deep Learning Model (75/25 split)
# R²: 0.1242
# MSE: 8699.7988
# MAE: 40.0277
# MAPE: 31.01 %
# ----------------------------------------

# %%
#75:25
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Split again for safety
split_ratio = 0.25
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(
    x_cleaned, y, test_size=split_ratio, random_state=42
)

# Scale
scaler_split = StandardScaler()
x_train_split_scaled = scaler_split.fit_transform(x_train_split)
x_test_split_scaled = scaler_split.transform(x_test_split)

# ---- MODEL VARIANTS ---- #

models = {}

# 1. Sigmoid activations + RMSprop optimizer
model_sigmoid = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='sigmoid'),
    tf.keras.layers.Dense(32, activation='sigmoid'),
    tf.keras.layers.Dense(16, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sigmoid.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005),
    metrics=['mae']
)
history_sigmoid = model_sigmoid.fit(x_train_split_scaled, y_train_split, epochs=300, verbose=0)
y_pred_sigmoid = model_sigmoid.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sigmoid, "Sigmoid + RMSprop")

# 2. Tanh activations + Adam optimizer + deeper net
model_tanh = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(32, activation='tanh'),
    tf.keras.layers.Dense(16, activation='tanh'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_tanh.compile(
    loss='mae',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['mae']
)
history_tanh = model_tanh.fit(x_train_split_scaled, y_train_split, epochs=400, verbose=0)
y_pred_tanh = model_tanh.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_tanh, "Tanh + Adam")

# 3. ReLU + SGD optimizer (classic)
model_sgd = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sgd.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    metrics=['mae']
)
history_sgd = model_sgd.fit(x_train_split_scaled, y_train_split, epochs=200, verbose=0)
y_pred_sgd = model_sgd.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sgd, "ReLU + SGD")

# 4. LeakyReLU + Adam + wider layers
model_leaky = tf.keras.Sequential([
    tf.keras.layers.Dense(256),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(128),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(64),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(1, activation='linear')
])
model_leaky.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
    metrics=['mae']
)
history_leaky = model_leaky.fit(x_train_split_scaled, y_train_split, epochs=500, verbose=0)
y_pred_leaky = model_leaky.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_leaky, "LeakyReLU + Adam")
# Out:
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Sigmoid + RMSprop
# R²: -0.0
# MSE: 9934.2314
# MAE: 59.7173
# MAPE: 76.89 %
# ----------------------------------------
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Tanh + Adam
# R²: 0.1851
# MSE: 8095.2305
# MAE: 37.0945
# MAPE: 27.49 %
# ----------------------------------------
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for ReLU + SGD
# R²: -0.0013
# MSE: 9946.4033
# MAE: 57.7506
# MAPE: 71.59 %
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for LeakyReLU + Adam
# R²: 0.3365
# MSE: 6591.1265
# MAE: 38.9761
# MAPE: 38.69 %
# ----------------------------------------

# %%
#70:30
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Split again for safety
split_ratio = 0.30
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(
    x_cleaned, y, test_size=split_ratio, random_state=42
)

# Scale
scaler_split = StandardScaler()
x_train_split_scaled = scaler_split.fit_transform(x_train_split)
x_test_split_scaled = scaler_split.transform(x_test_split)

# ---- MODEL VARIANTS ---- #

models = {}

# 1. Sigmoid activations + RMSprop optimizer
model_sigmoid = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='sigmoid'),
    tf.keras.layers.Dense(32, activation='sigmoid'),
    tf.keras.layers.Dense(16, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sigmoid.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005),
    metrics=['mae']
)
history_sigmoid = model_sigmoid.fit(x_train_split_scaled, y_train_split, epochs=300, verbose=0)
y_pred_sigmoid = model_sigmoid.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sigmoid, "Sigmoid + RMSprop")

# 2. Tanh activations + Adam optimizer + deeper net
model_tanh = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(32, activation='tanh'),
    tf.keras.layers.Dense(16, activation='tanh'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_tanh.compile(
    loss='mae',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['mae']
)
history_tanh = model_tanh.fit(x_train_split_scaled, y_train_split, epochs=400, verbose=0)
y_pred_tanh = model_tanh.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_tanh, "Tanh + Adam")

# 3. ReLU + SGD optimizer (classic)
model_sgd = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sgd.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    metrics=['mae']
)
history_sgd = model_sgd.fit(x_train_split_scaled, y_train_split, epochs=200, verbose=0)
y_pred_sgd = model_sgd.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sgd, "ReLU + SGD")

# 4. LeakyReLU + Adam + wider layers
model_leaky = tf.keras.Sequential([
    tf.keras.layers.Dense(256),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(128),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(64),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(1, activation='linear')
])
model_leaky.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
    metrics=['mae']
)
history_leaky = model_leaky.fit(x_train_split_scaled, y_train_split, epochs=500, verbose=0)
y_pred_leaky = model_leaky.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_leaky, "LeakyReLU + Adam")
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Sigmoid + RMSprop
# R²: 0.2714
# MSE: 7506.1396
# MAE: 45.0051
# MAPE: 47.3 %
# ----------------------------------------
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Tanh + Adam
# R²: 0.178
# MSE: 8468.4111
# MAE: 37.6421
# MAPE: 27.31 %
# ----------------------------------------
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for ReLU + SGD
# R²: -0.0021
# MSE: 10324.7461
# MAE: 62.846
# MAPE: 83.5 %
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for LeakyReLU + Adam
# R²: 0.2108
# MSE: 8130.8252
# MAE: 42.7534
# MAPE: 41.01 %
# ----------------------------------------

# %%
#85:15
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Split again for safety
split_ratio = 0.15
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(
    x_cleaned, y, test_size=split_ratio, random_state=42
)

# Scale
scaler_split = StandardScaler()
x_train_split_scaled = scaler_split.fit_transform(x_train_split)
x_test_split_scaled = scaler_split.transform(x_test_split)

# ---- MODEL VARIANTS ---- #

models = {}

# 1. Sigmoid activations + RMSprop optimizer
model_sigmoid = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='sigmoid'),
    tf.keras.layers.Dense(32, activation='sigmoid'),
    tf.keras.layers.Dense(16, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sigmoid.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005),
    metrics=['mae']
)
history_sigmoid = model_sigmoid.fit(x_train_split_scaled, y_train_split, epochs=300, verbose=0)
y_pred_sigmoid = model_sigmoid.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sigmoid, "Sigmoid + RMSprop")

# 2. Tanh activations + Adam optimizer + deeper net
model_tanh = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(32, activation='tanh'),
    tf.keras.layers.Dense(16, activation='tanh'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_tanh.compile(
    loss='mae',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['mae']
)
history_tanh = model_tanh.fit(x_train_split_scaled, y_train_split, epochs=400, verbose=0)
y_pred_tanh = model_tanh.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_tanh, "Tanh + Adam")

# 3. ReLU + SGD optimizer (classic)
model_sgd = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sgd.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    metrics=['mae']
)
history_sgd = model_sgd.fit(x_train_split_scaled, y_train_split, epochs=200, verbose=0)
y_pred_sgd = model_sgd.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sgd, "ReLU + SGD")

# 4. LeakyReLU + Adam + wider layers
model_leaky = tf.keras.Sequential([
    tf.keras.layers.Dense(256),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(128),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(64),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(1, activation='linear')
])
model_leaky.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
    metrics=['mae']
)
history_leaky = model_leaky.fit(x_train_split_scaled, y_train_split, epochs=500, verbose=0)
y_pred_leaky = model_leaky.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_leaky, "LeakyReLU + Adam")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for Sigmoid + RMSprop
# R²: 0.232
# MSE: 7322.9746
# MAE: 45.0601
# MAPE: 48.14 %
# ----------------------------------------
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for Tanh + Adam
# R²: 0.2001
# MSE: 7626.8013
# MAE: 35.9597
# MAPE: 26.76 %
# ----------------------------------------
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for ReLU + SGD
# R²: -0.0
# MSE: 9535.4736
# MAE: 58.3337
# MAPE: 74.18 %
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for LeakyReLU + Adam
# R²: 0.0693
# MSE: 8874.0479
# MAE: 44.7135
# MAPE: 43.96 %
# ----------------------------------------

# %%
#80:20
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Split again for safety
split_ratio = 0.20
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(
    x_cleaned, y, test_size=split_ratio, random_state=42
)

# Scale
scaler_split = StandardScaler()
x_train_split_scaled = scaler_split.fit_transform(x_train_split)
x_test_split_scaled = scaler_split.transform(x_test_split)

# ---- MODEL VARIANTS ---- #

models = {}

# 1. Sigmoid activations + RMSprop optimizer
model_sigmoid = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='sigmoid'),
    tf.keras.layers.Dense(32, activation='sigmoid'),
    tf.keras.layers.Dense(16, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sigmoid.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005),
    metrics=['mae']
)
history_sigmoid = model_sigmoid.fit(x_train_split_scaled, y_train_split, epochs=300, verbose=0)
y_pred_sigmoid = model_sigmoid.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sigmoid, "Sigmoid + RMSprop")

# 2. Tanh activations + Adam optimizer + deeper net
model_tanh = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(32, activation='tanh'),
    tf.keras.layers.Dense(16, activation='tanh'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_tanh.compile(
    loss='mae',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['mae']
)
history_tanh = model_tanh.fit(x_train_split_scaled, y_train_split, epochs=400, verbose=0)
y_pred_tanh = model_tanh.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_tanh, "Tanh + Adam")

# 3. ReLU + SGD optimizer (classic)
model_sgd = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sgd.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    metrics=['mae']
)
history_sgd = model_sgd.fit(x_train_split_scaled, y_train_split, epochs=200, verbose=0)
y_pred_sgd = model_sgd.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sgd, "ReLU + SGD")

# 4. LeakyReLU + Adam + wider layers
model_leaky = tf.keras.Sequential([
    tf.keras.layers.Dense(256),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(128),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(64),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(1, activation='linear')
])
model_leaky.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
    metrics=['mae']
)
history_leaky = model_leaky.fit(x_train_split_scaled, y_train_split, epochs=500, verbose=0)
y_pred_leaky = model_leaky.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_leaky, "LeakyReLU + Adam")
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for Sigmoid + RMSprop
# R²: -0.0001
# MSE: 10007.9268
# MAE: 59.6968
# MAPE: 77.09 %
# ----------------------------------------
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for Tanh + Adam
# R²: 0.1959
# MSE: 8046.8701
# MAE: 36.7189
# MAPE: 27.46 %
# ----------------------------------------
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for ReLU + SGD
# R²: -0.0043
# MSE: 10050.4248
# MAE: 56.1349
# MAPE: 67.52 %
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 📊 Results for LeakyReLU + Adam
# R²: 0.3081
# MSE: 6923.9536
# MAE: 39.7272
# MAPE: 37.89 %
# ----------------------------------------

# %%
#60:40
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Split again for safety
split_ratio = 0.40
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(
    x_cleaned, y, test_size=split_ratio, random_state=42
)

# Scale
scaler_split = StandardScaler()
x_train_split_scaled = scaler_split.fit_transform(x_train_split)
x_test_split_scaled = scaler_split.transform(x_test_split)

# ---- MODEL VARIANTS ---- #

models = {}

# 1. Sigmoid activations + RMSprop optimizer
model_sigmoid = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='sigmoid'),
    tf.keras.layers.Dense(32, activation='sigmoid'),
    tf.keras.layers.Dense(16, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sigmoid.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005),
    metrics=['mae']
)
history_sigmoid = model_sigmoid.fit(x_train_split_scaled, y_train_split, epochs=300, verbose=0)
y_pred_sigmoid = model_sigmoid.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sigmoid, "Sigmoid + RMSprop")

# 2. Tanh activations + Adam optimizer + deeper net
model_tanh = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(32, activation='tanh'),
    tf.keras.layers.Dense(16, activation='tanh'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_tanh.compile(
    loss='mae',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['mae']
)
history_tanh = model_tanh.fit(x_train_split_scaled, y_train_split, epochs=400, verbose=0)
y_pred_tanh = model_tanh.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_tanh, "Tanh + Adam")

# 3. ReLU + SGD optimizer (classic)
model_sgd = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
model_sgd.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    metrics=['mae']
)
history_sgd = model_sgd.fit(x_train_split_scaled, y_train_split, epochs=200, verbose=0)
y_pred_sgd = model_sgd.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_sgd, "ReLU + SGD")

# 4. LeakyReLU + Adam + wider layers
model_leaky = tf.keras.Sequential([
    tf.keras.layers.Dense(256),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(128),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(64),
    tf.keras.layers.LeakyReLU(alpha=0.1),
    tf.keras.layers.Dense(1, activation='linear')
])
model_leaky.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
    metrics=['mae']
)
history_leaky = model_leaky.fit(x_train_split_scaled, y_train_split, epochs=500, verbose=0)
y_pred_leaky = model_leaky.predict(x_test_split_scaled)
evaluate_model(y_test_split, y_pred_leaky, "LeakyReLU + Adam")
# Out:
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Sigmoid + RMSprop
# R²: 0.2064
# MSE: 8563.0508
# MAE: 48.006
# MAPE: 49.61 %
# ----------------------------------------
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for Tanh + Adam
# R²: 0.1447
# MSE: 9228.5098
# MAE: 39.5015
# MAPE: 28.3 %
# ----------------------------------------
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for ReLU + SGD
# R²: -0.0001
# MSE: 10791.0703
# MAE: 61.2291
# MAPE: 76.6 %
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📊 Results for LeakyReLU + Adam
# R²: 0.2641
# MSE: 7940.6177
# MAE: 41.5943
# MAPE: 39.71 %
# ----------------------------------------
